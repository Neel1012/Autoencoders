# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import matplotlib.pyplot as plt
from keras import layers
from keras.models import Model

# %%
dataframe = pd.read_csv('http://storage.googleapis.com/download.tensorflow.org/data/ecg.csv', header=None)
raw_data = dataframe.values

# %%
X = raw_data[:,:-1]
Y = raw_data[:,-1]

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2, random_state=21)

min_val = tf.reduce_min(X_train)
max_val = tf.reduce_max(X_train)

X_train = (X_train - min_val) / (max_val - min_val)
X_test = (X_test - min_val) / (max_val - min_val)

X_train = tf.cast(X_train, tf.float32)
X_test = tf.cast(X_test, tf.float32)

# %% [markdown]
# 64+8+1

# %%
ls = np.arange(1,21)
train_loss = np.arange(0,20).astype('float64')
test_loss = np.arange(0,20).astype('float64')

for i in ls:
  class AnomalyDetector(Model):
    def __init__(self):
      super(AnomalyDetector, self).__init__()
      self.encoder = tf.keras.Sequential([
        layers.Dense(64, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(i, activation="linear")]) 

      self.decoder = tf.keras.Sequential([
        layers.Dense(32, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(140, activation="sigmoid")])

    def call(self, x):
      encoded = self.encoder(x)
      decoded = self.decoder(encoded)
      return decoded

  autoencoder = AnomalyDetector()

  autoencoder.compile(optimizer='adam', loss='mae')

  history = autoencoder.fit(X_train, X_train, 
            epochs=1000, 
            batch_size=512,
            validation_data=(X_test, X_test),
            shuffle=True)

  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.show()

  reconstructions = autoencoder.predict(X_train)
  train_loss[i-1] = (np.mean(tf.keras.losses.mae(reconstructions, X_train).numpy()))

  reconstructions11 = autoencoder.predict(X_test)
  test_loss[i-1] = (np.mean(tf.keras.losses.mae(reconstructions11, X_test).numpy()))
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 1s 24ms/step - loss: 0.0547 - val_loss: 0.0529
# Epoch 2/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0518 - val_loss: 0.0498
# Epoch 3/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0480 - val_loss: 0.0453
# Epoch 4/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0430 - val_loss: 0.0406
# Epoch 5/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0385 - val_loss: 0.0368
# Epoch 6/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0350 - val_loss: 0.0339
# Epoch 7/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0324 - val_loss: 0.0318
# Epoch 8/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0305 - val_loss: 0.0301
# Epoch 9/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0291 - val_loss: 0.0290
# Epoch 10/1000
# ...

# %%
plt.plot(ls,train_loss, label = 'Train loss')
plt.plot(ls,test_loss, label = 'Test_loss')
plt.xlabel('Latent space')
plt.ylabel('Error mae')
plt.legend()
plt.grid()
plt.axis('tight')
plt.show()
print(test_loss)
# Out:
# [0.01682591 0.01230473 0.01031243 0.00950753 0.00837772 0.0082103
#  0.00781838 0.00707914 0.00698618 0.00689491 0.00627214 0.0064638
#  0.00623349 0.00618112 0.00658082 0.00619932 0.00638704 0.00606949
#  0.0064706  0.00620108]
